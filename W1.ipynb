# %%
# !pip install yfinance --upgrade
# Out:
# Requirement already satisfied: yfinance in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: requests>=2.31 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\nguyen ho tuyen\appdata\roaming\python\python312\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: pycparser in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nguyen ho tuyen\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.4.0)

# %% [markdown]
# #Price-volume data: open, high, low, close (OHLC),
# adjusted prices, volume

# %%
import yfinance as yf
from datetime import datetime, timedelta

# --- Ngày kết thúc: 11/10/2025 ---
end_date = datetime(2025, 10, 11)

# --- Ngày bắt đầu: lùi 10 năm ---
start_date = end_date - timedelta(days=365 * 10)

# %%
tickers = ["AAPL", "MSFT", "GOOG", "AMZN"]

for t in tickers:
    df = yf.download(t, start=start_date, end=end_date, progress=False, auto_adjust=False)
    globals()[f"df_{t}"] = df  # gán trực tiếp vào biến df_AAPL, df_MSFT, ...
    print(f"Downloaded {t}: {len(df)} rows")

# Kiểm tra
for t in tickers:
    print(f"\n{t}:")
    print(globals()[f"df_{t}"].head())
# Out:
# Downloaded AAPL: 2513 rows
# Downloaded MSFT: 2513 rows
# Downloaded GOOG: 2513 rows
# Downloaded AMZN: 2513 rows
#
# AAPL:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-10-14  24.767004  27.552500  27.879999  27.389999  27.822500  177849600
# 2015-10-15  25.137802  27.965000  28.025000  27.622499  27.732500  150694000
# 2015-10-16  24.953529  27.760000  28.000000  27.632500  27.945000  156930400
# 2015-10-19  25.108593  27.932501  27.937500  27.527500  27.700001  119036800
# 2015-10-20  25.567030  28.442499  28.542500  27.705000  27.834999  195871200
#
# MSFT:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2015-10-14  40.675846  46.680000  47.099998  46.529999  46.650002  24697800
# 2015-10-15  40.963387  47.009998  47.029999  46.529999  47.009998  27189400
# 2015-10-16  41.399075  47.509998  47.540001  46.900002  47.020000  26450300
# 2015-10-19  41.494919  47.619999  47.880001  47.020000  47.419998  29387600
# 2015-10-20  41.625633  47.770000  47.810001  47.020000  47.439999  30802200
#
# GOOG:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           GOOG       GOOG       GOOG       GOOG       GOOG      GOOG
# Date
# 2015-10-14  32.336712  32.557999  32.969501  32.442501  32.660500  28310000
# 2015-10-15  32.862118  33.087002  33.156502  32.723000  32.733002  37714000
# 2015-10-16  32.884956  33.110001  33.248501  32.860001  33.205502  32222000
# 2015-10-19  33.078636  33.305000  33.341000  32.979000  33.058998  29546000
# 2015-10-20  32.293015  32.514000  33.236000  32.209751  33.202000  49964000
#
# AMZN:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           AMZN       AMZN       AMZN       AMZN       AMZN      AMZN
# Date
# 2015-10-14  27.241501  27.241501  27.612499  26.983999  27.566999  71642000
# 2015-10-15  28.122000  28.122000  28.150000  27.350000  27.387501  98740000
# 2015-10-16  28.538000  28.538000  28.547001  28.015499  28.263500  86316000
# 2015-10-19  28.657499  28.657499  28.950001  28.368999  28.538000  87508000
# 2015-10-20  28.044001  28.044001  28.650000  27.764000  28.600000  86924000

# %%
import pandas as pd

def clean_stock_df(df, symbol):
    """
    Làm phẳng MultiIndex, thêm cột Symbol, 
    làm sạch header trùng ('Date', 'Ticker', ...)
    """
    # Làm phẳng MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)

    # Đưa Date ra khỏi index
    df = df.reset_index()

    # Đặt lại tên cột đầu tiên thành "Date"
    df = df.rename(columns={df.columns[0]: "Date"})

    # Thêm cột Symbol
    df["Symbol"] = symbol

    # Loại bỏ các dòng header trùng lặp hoặc lỗi
    df = df[~df["Date"].isin(["Date", "Ticker"])]
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
    df = df.dropna(subset=["Date"])

    # Sắp xếp lại cột
    cols = ["Symbol", "Date", "Adj Close", "Close", "High", "Low", "Open", "Volume"]
    df = df[cols].reset_index(drop=True)

    return df


# Áp dụng cho 4 mã
df_AAPL_clean = clean_stock_df(df_AAPL, "AAPL")
df_MSFT_clean = clean_stock_df(df_MSFT, "MSFT")
df_GOOG_clean = clean_stock_df(df_GOOG, "GOOG")
df_AMZN_clean = clean_stock_df(df_AMZN, "AMZN")

# %%
# Gộp tất cả lại thành 1 DataFrame tổng
df_all = pd.concat([df_AAPL_clean, df_MSFT_clean, df_GOOG_clean, df_AMZN_clean], ignore_index=True)

# %%
df_all
# Out:
# Price Symbol       Date   Adj Close       Close        High         Low  \
# 0       AAPL 2015-10-14   24.767004   27.552500   27.879999   27.389999
# 1       AAPL 2015-10-15   25.137802   27.965000   28.025000   27.622499
# 2       AAPL 2015-10-16   24.953529   27.760000   28.000000   27.632500
# 3       AAPL 2015-10-19   25.108593   27.932501   27.937500   27.527500
# 4       AAPL 2015-10-20   25.567030   28.442499   28.542500   27.705000
# ...      ...        ...         ...         ...         ...         ...
# 10047   AMZN 2025-10-06  220.899994  220.899994  221.729996  216.029999
# 10048   AMZN 2025-10-07  221.779999  221.779999  222.889999  220.169998
# 10049   AMZN 2025-10-08  225.220001  225.220001  226.729996  221.190002
# 10050   AMZN 2025-10-09  227.740005  227.740005  228.210007  221.750000
# 10051   AMZN 2025-10-10  216.369995  216.369995  228.250000  216.000000
#
# Price        Open     Volume
# 0       27.822500  177849600
# 1       27.732500  150694000
# 2       27.945000  156930400
# 3       27.700001  119036800
# 4       27.834999  195871200
# ...           ...        ...
# 10047  221.000000   43690900
# 10048  220.880005   31194700
# 10049  222.919998   46686000
# 10050  225.000000   46412100
# 10051  226.210007   71966500
#
# [10052 rows x 8 columns]
